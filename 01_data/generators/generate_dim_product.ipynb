# %% [markdown]
# # Generate dim_product
# Creates the product dimension and writes data/dim_product.csv.

# %%
from pathlib import Path

import numpy as np
import pandas as pd

SEED = 42
np.random.seed(SEED)

def find_project_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / 'README.md').exists() and (candidate / '01_data').exists():
            return candidate
    return current

products = [
    ('CHK_STD', 'Checking Standard', 'Checking'),
    ('CHK_PRM', 'Checking Premium', 'Checking'),
    ('SVG_STD', 'Savings Standard', 'Savings'),
    ('SVG_HY', 'Savings High Yield', 'Savings'),
    ('CRD_CL', 'Credit Card Classic', 'Cards'),
    ('CRD_PL', 'Credit Card Platinum', 'Cards'),
    ('LN_PER', 'Personal Loan', 'Lending'),
    ('LN_AUTO', 'Auto Loan', 'Lending'),
    ('MRT_FIX', 'Mortgage Fixed', 'Mortgage'),
    ('MRT_VAR', 'Mortgage Variable', 'Mortgage'),
]

dim_product = pd.DataFrame(products, columns=['product_code', 'product_name', 'product_category'])
dim_product.insert(0, 'product_key', np.arange(1, len(dim_product) + 1, dtype=np.int32))

output_dir = find_project_root() / '01_data' / 'raw'
output_dir.mkdir(parents=True, exist_ok=True)
output_path = output_dir / 'dim_product.csv'
dim_product.to_csv(output_path, index=False)

print(f'Rows: {len(dim_product)}')
print(f'Wrote: {output_path}')
dim_product.head()
# Out:
# Rows: 10
# Wrote: C:\Users\msario\OneDrive - Microsoft\2026\00_All About Databricks\Databricks-Finance\01_data\raw\dim_product.csv
#    product_key product_code         product_name product_category
# 0            1      CHK_STD    Checking Standard         Checking
# 1            2      CHK_PRM     Checking Premium         Checking
# 2            3      SVG_STD     Savings Standard          Savings
# 3            4       SVG_HY   Savings High Yield          Savings
# 4            5       CRD_CL  Credit Card Classic            Cards
